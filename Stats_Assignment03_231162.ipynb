# %% [markdown]
# <a href="https://colab.research.google.com/github/abdulehsan/Assignments/blob/main/Stats_Assignment03_231162.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **About Dataset**
#
# **Purpose:** The dataset is designed to explore the potential relationship between lifestyle habits and the probability of developing cancer.
#
# **Variables:**
#
#
# *   Sr No.: A unique identifier for each observation.
# *   Smoking Habit: Categorizes individuals based on their smoking frequency (e.g., Heavy, Moderate, Occasional, None).
#
# *   Drinking Habit: Categorizes individuals based on their alcohol consumption frequency (e.g., Frequent, Occasional, None).
# *   Biking Habit: Measures the frequency of biking activity (e.g., High, Medium, Low).
# *   Walking Habit: Measures the frequency of walking activity (e.g., High, Medium, Low).
# *   Jogging Habit: Measures the frequency of jogging activity (e.g., High, Medium, Low).
# *   Probability of Cancer: A numerical value representing the estimated likelihood of developing cancer, ranging from 0 to 1.
#
# **Assumptions:**
#
# The dataset assumes a causal relationship between lifestyle habits and cancer risk. However, correlation does not necessarily imply causation, and other factors may influence cancer development.
# The probability of cancer is a simplified representation and may vary based on individual factors, genetics, and environmental influences.

# %%
pd.set_option('display.width', 0)
pd.set_option('display.max_colwidth', None)
print(data.to_string(index=False))
# Out:
#  Sr No. Smoking Habit Drinking Habit Biking Habit Walking Habit Jogging Habit  Probability of Cancer
#       1         Heavy       Frequent          Low           Low           Low                   0.80
#       2    Occasional       Moderate         High          High          High                   0.20
#       3           NaN            NaN         High          High          High                   0.10
#       4         Heavy       Frequent          Low           Low           Low                   0.90
#       5      Moderate     Occasional       Medium        Medium        Medium                   0.40
#       6           NaN            NaN         High          High          High                   0.05
#       7         Heavy       Frequent          Low           Low           Low                   0.75
#       8      Moderate     Occasional       Medium        Medium        Medium                   0.30
#       9           NaN            NaN         High          High          High                   0.02
#      10         Heavy       Frequent          Low           Low           Low                   0.85
#      11      Moderate     Occasional       Medium        Medium        Medium                   0.45
#      12           NaN            NaN         High          High          High                   0.01
#      13         Heavy       Frequent          Low           Low           Low                   0.90
#      14      Moderate     Occasional       Medium        Medium        Medium                   0.35
#      15           NaN            NaN         High          High          High                   0.03
#      16         Heavy       Frequent          Low           Low           Low                   0.70
#      17      Moderate     Occasional       Medium        Medium        Medium                   0.40
#      18           NaN            NaN         High          High          High                   0.05
#      19         Heavy       Frequent          Low           Low           Low                   0.80
#      20      Moderate     Occasional       Medium        Medium        Medium                   0.30
#      21           NaN            NaN         High          High          High                   0.02
#      22         Heavy       Frequent          Low           Low           Low                   0.90
#      23      Moderate     Occasional       Medium        Medium        Medium                   0.40
#      24           NaN            NaN         High          High          High                   0.01
#      25         Heavy       Frequent          Low           Low           Low                   0.75
#      26      Moderate     Occasional       Medium        Medium        Medium                   0.35
#      27           NaN            NaN         High          High          High                   0.03
#      28         Heavy       Frequent          Low           Low           Low                   0.80
#      29      Moderate     Occasional       Medium        Medium        Medium                   0.40
#      30           NaN            NaN         High          High          High                   0.05
#      31         Heavy       Frequent          Low           Low           Low                   0.90
#      32      Moderate     Occasional       Medium        Medium        Medium                   0.30
#      33           NaN            NaN         High          High          High                   0.02
#      34         Heavy       Frequent          Low           Low           Low                   0.75
#      35      Moderate     Occasional       Medium        Medium        Medium                   0.45
#      36           NaN            NaN         High          High          High                   0.01
#      37         Heavy       Frequent          Low           Low           Low                   0.80
#      38      Moderate     Occasional       Medium        Medium        Medium                   0.35
#      39           NaN            NaN         High          High          High                   0.03
#      40         Heavy       Frequent          Low           Low           Low                   0.90
#      41      Moderate     Occasional       Medium        Medium        Medium                   0.40
#      42           NaN            NaN         High          High          High                   0.05
#      43         Heavy       Frequent          Low           Low           Low                   0.70
#      44      Moderate     Occasional       Medium        Medium        Medium                   0.30
#      45           NaN            NaN         High          High          High                   0.02
#      46         Heavy       Frequent          Low           Low           Low                   0.80
#      47      Moderate     Occasional       Medium        Medium        Medium                   0.40
#      48           NaN            NaN         High          High          High                   0.01
#      49         Heavy       Frequent          Low           Low           Low                   0.75
#      50      Moderate     Occasional       Medium        Medium        Medium                   0.35

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
# !pip install -q panda
# !pip install scipy
# !pip install matplotlib
# Out:
#   Preparing metadata (setup.py) ... done
#   Building wheel for panda (setup.py) ... done

# %% [markdown]
# Calculating Mean, Median, Mode of Probability of Cancer

# %%
import pandas as pd
from scipy import stats

data = pd.read_csv('drive/MyDrive/Dataset/cancer-probabilities.csv')

mean_cases = data['Probability of Cancer'].mean()
median_cases = data['Probability of Cancer'].median()
mode_cases = data['Probability of Cancer'].mode()
print(f"Mean: {mean_cases}, Median: {median_cases}, Mode: {mode_cases[0]}")
# Out:
# Mean: 0.4072, Median: 0.375, Mode: 0.4

# %%
import matplotlib.pyplot as plt

plt.hist(data['Probability of Cancer'], bins=50, edgecolor='black')
plt.title('Histogram of Probability of Cancer')
plt.xlabel('Probabilities')
plt.ylabel('Frequency')
plt.show()

# %%
top_cases = data['Probability of Cancer'].value_counts().nlargest(10)
plt.pie(top_cases, labels=top_cases.index, autopct='%1.1f%%', startangle=90)
plt.title('Top 10 Cases Distribution')
plt.show()
